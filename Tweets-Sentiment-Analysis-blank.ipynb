# %%
#!pip install tweepy
#!pip install textblob
import re # regular expression / regex
import tweepy #Collect tweets
from tweepy import OAuthHandler # Authentication
from textblob import TextBlob # provides text mining, text analysis and text processing modules
querytext = "rahul gandhi" #any keyword
class TwitterClient(object):
    '''
    Generic Twitter Class for sentiment analysis.
    '''
    def __init__(self):
        '''
        Class constructor or initialization method.
        '''
        # keys and tokens from the Twitter Dev Console
        consumer_key = 'ts8RhO1B1qIzdSLaDsaise89a'
        consumer_secret = 'A4ZawHMrKiAaoxfQhmjrW5F2gWwgjh9jhCuvczy8cymLaTJfES'
        access_token = '929606650415136768-Ok0ca8lkQk7oD8xNUqKWKg9VyoEXJRV'
        access_token_secret = '5mJm07yiPpvFB7M4Z9l4yaip4k6gvSpL2mEMMs6sEXjqX'
 
        # attempt authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Authentication Failed")
 
    def clean_tweet(self, tweet):
        '''
        Utility function to clean tweet text by removing links, special characters
        using simple regex statements.
        '''
        return ' '.join(re.sub("/!@%&", " ", tweet).split())
 
    def get_tweet_sentiment(self, tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
 
    def get_tweets(self, query, count = 10):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets
        tweets = []
 
        try:
            # call twitter api to fetch tweets
            fetched_tweets = self.api.search(q = query, count = count)
 
            # parsing tweets one by one
            for tweet in fetched_tweets:
                # empty dictionary to store required params of a tweet
                parsed_tweet = {}
 
                # saving text of tweet
                parsed_tweet['text'] = tweet.text
                # saving sentiment of tweet
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
 
                # appending parsed tweet to tweets list
                if tweet.retweet_count > 0:
                    # if tweet has retweets, ensure that it is appended only once
                    if parsed_tweet not in tweets:
                        tweets.append(parsed_tweet)
                else:
                    tweets.append(parsed_tweet)
 
            # return parsed tweets
            return tweets
 
        except tweepy.TweepError as e:
            # print error (if any)
            print("Error : " + str(e))
def main():
    # creating object of TwitterClient Class
    api = TwitterClient()
    # calling function to get tweets
    tweets = api.get_tweets(query = querytext, count = 1000)
 
    # picking positive tweets from tweets
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
    # percentage of positive tweets
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
    # picking negative tweets from tweets
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
    # percentage of negative tweets
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
    # percentage of neutral tweets
    print("Neutral tweets percentage: {} %".format(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets)))
    print("\n\n Total Tweets:",len(tweets))
    # printing first 5 positive tweets
    print("\n\nPositive tweets:")
    for tweet in ptweets[:10]:
        print(tweet['text'])
 
    # printing first 5 negative tweets
    print("\n\nNegative tweets:")
    for tweet in ntweets[:15]:
        print(tweet['text'])
main()

# %%
# Out:
# Positive tweets percentage: 28.571428571428573 %
# Negative tweets percentage: 11.11111111111111 %
# Neutral tweets percentage: 60.317460317460316 %
#
#
#  Total Tweets: 63
#
#
# Positive tweets:
# @JusticeArnabG @RahulGandhi Ghabraye nhi sir 2019 me is kram ka badla janta le legi. Agar social media me mansarove… https://t.co/fJUdVI8xql
# RT @Shehzad_Ind: Rahul Gandhi 's abusive Social Media ally Sanjiv Bhatt detained say sources;being interrogated by CID (crime) in a drug re…
# RT @indiasecular: Rahul Gandhi for Indian Media Presstitutes and Arun Sorrys is a great Leader future PM alternative to Mudi aa-haa
# For for…
# Rahul Gandhi, forget that, Congress will win 2019 Election.
# RT @ggiittiikkaa: Dismissed IPS officer &amp; Rahul Gandhi's social media troll - Sanjiv Bhatt - arrested by Guj CID for drug peddling &amp; planti…
# RT @CNNews69: #BREAKING : @sagarikaghose &amp; @sardesairajdeep confirmed Rahul Gandhi didn't ate chicken/Pork after tasting his stool. https:/…
# Sad but true, our country is in the hands of people who are against intellectuals and free thinkers. Leaders like A… https://t.co/QL40Z9Nz2n
# RT @sampitroda: Please look at the @dna link here -  https://t.co/nUrUyHVCzl.
# Another #LIE and more #lies.
# Why do Indian media do this ?…
# @TimeTideRide @StonerboyTed @chetan_bhagat Capable toh bas Rahul Gandhi hai ... nehi???
#
# Mazaak ka joh hud hoti hai… https://t.co/1FGnBMFQzV
# RT @himanshu8147: #CGL17Delayed when will u declare cgl 17 result it almost take more than 1 year.I think bjp is in overconfident for 2019…
#
#
# Negative tweets:
# RT @prafullaketkar: Having failed to convince and inspire confidence among the voters in BHARAT, Rahul Gandhi (RG) is going around foreign…
# RT @TiimesHow: Just In : Shri Rahul Gandhi Ji did not eat Non Veg food in Nepal. The Chicken he ate used to eat only grains so it was a Veg…
# RT @BhaavnaArora: [Rahul Gandhi eats Pork, Beef and Chicken while visiting holy Kailash Mansarovar]
# Rahul Gandhi is not Janeudhari but more…
# RT @rakeshsunrise: Congress and its supporters have a special reason to hate Irani. She had dared to contest the Lok Sabha elections agains…
# RT @MyNation: VIEWS | Abhishek Banerjee writes, "As the #Congress loses its stakes in governing #India, the party seems to be opening its d…
# Congress and its supporters have a special reason to hate Irani. She had dared to contest the Lok Sabha elections a… https://t.co/YLzwMdOmXt
# RT @ckarunkumar: In 2012 a woman in south India tried to show black flag to Sonia Gandhi. It was called "discipline" &amp; "crowd control".  In…
